# %% [markdown]
# Notes
#
# In functions you can edit but not modify (change the location in memory) a global variable/

# %%
x = x or [] # shoryt-circuiting operator

# %% [markdown]
# Errors
#
# ExceptionErrors are all runtime errors.

# %% [markdown]
# The following doesn't work. Define everything before execution.

# %%
def a():
    b()

a()

def b():
    return None

# %%
try:
    a()
except Exception as e:
    print("Error:", e)
else:
    b()
finally:
    b()

# %% [markdown]
# Code inside try block should be as small as possible.
