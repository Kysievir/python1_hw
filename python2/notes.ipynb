# %% [markdown]
# Classes
# 1. isinstance() respects the parent class.
# 2. Private attributes cannot be accessed by subclasses

# %%
import functools

def timethis(func):

    @functools.wraps(func)
    def inner(*args, **kwargs):
        print(func.__name__, end="...")
    
    return inner

# %%
locals()

# %% [markdown]
# Decorators
# 1. nonlocal is needed to access immutable from outside the function name space. Mutable objects like dictionary can simply be referred to.
